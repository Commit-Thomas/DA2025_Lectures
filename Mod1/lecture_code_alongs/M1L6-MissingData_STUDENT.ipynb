# %% [markdown]
# # M1L6 Identifying & Handling Missing Data
#
#  We'll be working with the same Austin Animal Center Intakes dataset from the previous lecture, which contains information about animals entering the Austin Animal Center.
#
# ### **Dataset:** [Austin Animal Center Intakes](https://catalog.data.gov/dataset/austin-animal-center-intakes) -- This is also in your data folder
#
# ### **Objectives:**
#
#  1.  Identify Columns with Missing Data
#  2.  Handle missing data by dropping data and using imputation techniques

# %% [markdown]
# ## Step 1:  Import pandas and numpy

# %%
#Import packages 

import pandas as pd
import numpy as np

# %% [markdown]
# ## Step 2:  Load in the data and save it as `df`

# %%
df=pd.read_csv('/Users/Marcy_Student/Downloads/Austin_Animal_Center_Intakes__10_01_2013_to_05_05_2025_.csv')

# %% [markdown]
# ## Step 3:  Look at the data (can you think of ONE method that we can use to quickly see column names and how many non-null values exist in each column)
#
# **Instructor if they draw a blank say what method can tell us data types, column names, the number of non-null values etc**

# %%
df.describe
# Out:
# <bound method NDFrame.describe of        Animal ID    Name                DateTime     MonthYear  \
# 0        A521520    Nina  10/01/2013 07:51:00 AM  October 2013
# 1        A664235     NaN  10/01/2013 08:33:00 AM  October 2013
# 2        A664236     NaN  10/01/2013 08:33:00 AM  October 2013
# 3        A664237     NaN  10/01/2013 08:33:00 AM  October 2013
# 4        A664233  Stevie  10/01/2013 08:53:00 AM  October 2013
# ...          ...     ...                     ...           ...
# 173807   A929690     NaN  05/03/2025 11:18:00 PM      May 2025
# 173808   A929717     NaN  05/04/2025 03:14:00 PM      May 2025
# 173809   A929724     NaN  05/04/2025 07:43:00 PM      May 2025
# 173810   A929725  Oswold  05/04/2025 10:55:00 PM      May 2025
# 173811   A929635     NaN  05/04/2025 11:44:00 PM      May 2025
#
#                                   Found Location    Intake Type  \
# 0                        Norht Ec in Austin (TX)          Stray
# 1                            Abia in Austin (TX)          Stray
# 2                            Abia in Austin (TX)          Stray
# 3                            Abia in Austin (TX)          Stray
# 4                 7405 Springtime in Austin (TX)          Stray
# ...                                          ...            ...
# 173807           8038 Exchange Dr in Austin (TX)          Stray
# 173808                               Austin (TX)  Public Assist
# 173809  7105 Providence Ave Apt 3 in Austin (TX)          Stray
# 173810         1501  Red River St in Austin (TX)  Public Assist
# 173811              708 Simonetti in Austin (TX)          Stray
#
#        Intake Condition Animal Type Sex upon Intake Age upon Intake  \
# 0                Normal         Dog   Spayed Female         7 years
# 1                Normal         Cat         Unknown          1 week
# 2                Normal         Cat         Unknown          1 week
# 3                Normal         Cat         Unknown          1 week
# 4               Injured         Dog   Intact Female         3 years
# ...                 ...         ...             ...             ...
# 173807          Injured         Dog     Intact Male         2 years
# 173808           Normal         Dog     Intact Male          1 year
# 173809           Normal       Other         Unknown          1 year
# 173810           Normal         Dog     Intact Male        10 years
# 173811           Normal         Cat   Spayed Female         2 years
#
#                                Breed         Color
# 0       Border Terrier/Border Collie     White/Tan
# 1             Domestic Shorthair Mix  Orange/White
# 2             Domestic Shorthair Mix  Orange/White
# 3             Domestic Shorthair Mix  Orange/White
# 4                       Pit Bull Mix    Blue/White
# ...                              ...           ...
# 173807              Belgian Malinois   Brown/Black
# 173808                  Shih Tzu Mix    White/Blue
# 173809                     Rabbit Sh     Tan/White
# 173810                     Boxer Mix     Tan/White
# 173811            Domestic Shorthair   Black/White
#
# [173812 rows x 12 columns]>

# %% [markdown]
# ## Step 4:  Assign a missing indicator to those rows who have missing animal names

# %%
None
df.head('Missing Name').isnull() #optional line to see changes
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 2
#       1 None
# ----> 2 df.head('Missing Name').isnull() #optional line to see changes
#
# File /opt/miniconda3/envs/data-analysis-env/lib/python3.9/site-packages/pandas/core/generic.py:5893, in NDFrame.head(self, n)
#    5891 if using_copy_on_write():
#    5892     return self.iloc[:n].copy()
# -> 5893 return self.iloc[:n]
#
# File /opt/miniconda3/envs/data-analysis-env/lib/python3.9/site-packages/pandas/core/indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
#    1189 maybe_callable = com.apply_if_callable(key, self.obj)
#    1190 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191 return self._getitem_axis(maybe_callable, axis=axis)
#
# File /opt/miniconda3/envs/data-analysis-env/lib/python3.9/site-packages/pandas/core/indexing.py:1729, in _iLocIndexer._getitem_axis(self, key, axis)
#    1723     raise IndexError(
#    1724         "DataFrame indexer is not allowed for .iloc\n"
#    1725         "Consider using .loc for automatic alignment."
#    1726     )
#    1728 if isinstance(key, slice):
# -> 1729     return self._get_slice_axis(key, axis=axis)
#    1731 if is_iterator(key):
#    1732     key = list(key)
#
# File /opt/miniconda3/envs/data-analysis-env/lib/python3.9/site-packages/pandas/core/indexing.py:1764, in _iLocIndexer._get_slice_axis(self, slice_obj, axis)
#    1761     return obj.copy(deep=False)
#    1763 labels = obj._get_axis(axis)
# -> 1764 labels._validate_positional_slice(slice_obj)
#    1765 return self.obj._slice(slice_obj, axis=axis)
#
# File /opt/miniconda3/envs/data-analysis-env/lib/python3.9/site-packages/pandas/core/indexes/base.py:4198, in Index._validate_positional_slice(self, key)
#    4193 """
#    4194 For positional indexing, a slice must have either int or None
#    4195 for each of start, stop, and step.
#    4196 """
#    4197 self._validate_indexer("positional", key.start, "iloc")
# -> 4198 self._validate_indexer("positional", key.stop, "iloc")
#    4199 self._validate_indexer("positional", key.step, "iloc")
#
# File /opt/miniconda3/envs/data-analysis-env/lib/python3.9/site-packages/pandas/core/indexes/base.py:6697, in Index._validate_indexer(self, form, key, kind)
#    6692 """
#    6693 If we are positional indexer, validate that we have appropriate
#    6694 typed bounds must be an integer.
#    6695 """
#    6696 if not lib.is_int_or_none(key):
# -> 6697     self._raise_invalid_indexer(form, key)
#
# File /opt/miniconda3/envs/data-analysis-env/lib/python3.9/site-packages/pandas/core/indexes/base.py:4301, in Index._raise_invalid_indexer(self, form, key, reraise)
#    4299 if reraise is not lib.no_default:
#    4300     raise TypeError(msg) from reraise
# -> 4301 raise TypeError(msg)
#
# TypeError: cannot do positional indexing on RangeIndex with these indexers [Missing Name] of type str

# %% [markdown]
# ## Step 5:  Many names are missing let's fill this in with "UNKNOWN"

# %%
df['Name'].fillna("Unkown",inplace=True)
df.head() #optional line to see changes
# Out:
#   Animal ID    Name                DateTime     MonthYear  \
# 0   A521520    Nina  10/01/2013 07:51:00 AM  October 2013
# 1   A664235  Unkown  10/01/2013 08:33:00 AM  October 2013
# 2   A664236  Unkown  10/01/2013 08:33:00 AM  October 2013
# 3   A664237  Unkown  10/01/2013 08:33:00 AM  October 2013
# 4   A664233  Stevie  10/01/2013 08:53:00 AM  October 2013
#
#                    Found Location Intake Type Intake Condition Animal Type  \
# 0         Norht Ec in Austin (TX)       Stray           Normal         Dog
# 1             Abia in Austin (TX)       Stray           Normal         Cat
# 2             Abia in Austin (TX)       Stray           Normal         Cat
# 3             Abia in Austin (TX)       Stray           Normal         Cat
# 4  7405 Springtime in Austin (TX)       Stray          Injured         Dog
#
#   Sex upon Intake Age upon Intake                         Breed         Color
# 0   Spayed Female         7 years  Border Terrier/Border Collie     White/Tan
# 1         Unknown          1 week        Domestic Shorthair Mix  Orange/White
# 2         Unknown          1 week        Domestic Shorthair Mix  Orange/White
# 3         Unknown          1 week        Domestic Shorthair Mix  Orange/White
# 4   Intact Female         3 years                  Pit Bull Mix    Blue/White

# %% [markdown]
# ## Step 6:  There is ony one column with 'Age' missing; let's drop it for now

# %%
df['Sex upon Intake'].isnull().sum
df.info() #optional line to see changes
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 173812 entries, 0 to 173811
# Data columns (total 12 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Animal ID         173812 non-null  object
#  1   Name              123821 non-null  object
#  2   DateTime          173812 non-null  object
#  3   MonthYear         173812 non-null  object
#  4   Found Location    173812 non-null  object
#  5   Intake Type       173812 non-null  object
#  6   Intake Condition  173812 non-null  object
#  7   Animal Type       173812 non-null  object
#  8   Sex upon Intake   173811 non-null  object
#  9   Age upon Intake   173812 non-null  object
#  10  Breed             173812 non-null  object
#  11  Color             173812 non-null  object
# dtypes: object(12)
# memory usage: 15.9+ MB

# %%
df.dropna(subset= ('Sex upon Intake'))
# Out:
#        Animal ID    Name                DateTime     MonthYear  \
# 0        A521520    Nina  10/01/2013 07:51:00 AM  October 2013
# 1        A664235     NaN  10/01/2013 08:33:00 AM  October 2013
# 2        A664236     NaN  10/01/2013 08:33:00 AM  October 2013
# 3        A664237     NaN  10/01/2013 08:33:00 AM  October 2013
# 4        A664233  Stevie  10/01/2013 08:53:00 AM  October 2013
# ...          ...     ...                     ...           ...
# 173807   A929690     NaN  05/03/2025 11:18:00 PM      May 2025
# 173808   A929717     NaN  05/04/2025 03:14:00 PM      May 2025
# 173809   A929724     NaN  05/04/2025 07:43:00 PM      May 2025
# 173810   A929725  Oswold  05/04/2025 10:55:00 PM      May 2025
# 173811   A929635     NaN  05/04/2025 11:44:00 PM      May 2025
#
#                                   Found Location    Intake Type  \
# 0                        Norht Ec in Austin (TX)          Stray
# 1                            Abia in Austin (TX)          Stray
# 2                            Abia in Austin (TX)          Stray
# 3                            Abia in Austin (TX)          Stray
# 4                 7405 Springtime in Austin (TX)          Stray
# ...                                          ...            ...
# 173807           8038 Exchange Dr in Austin (TX)          Stray
# 173808                               Austin (TX)  Public Assist
# 173809  7105 Providence Ave Apt 3 in Austin (TX)          Stray
# 173810         1501  Red River St in Austin (TX)  Public Assist
# 173811              708 Simonetti in Austin (TX)          Stray
#
#        Intake Condition Animal Type Sex upon Intake Age upon Intake  \
# 0                Normal         Dog   Spayed Female         7 years
# 1                Normal         Cat         Unknown          1 week
# 2                Normal         Cat         Unknown          1 week
# 3                Normal         Cat         Unknown          1 week
# 4               Injured         Dog   Intact Female         3 years
# ...                 ...         ...             ...             ...
# 173807          Injured         Dog     Intact Male         2 years
# 173808           Normal         Dog     Intact Male          1 year
# 173809           Normal       Other         Unknown          1 year
# 173810           Normal         Dog     Intact Male        10 years
# 173811           Normal         Cat   Spayed Female         2 years
#
#                                Breed         Color
# 0       Border Terrier/Border Collie     White/Tan
# 1             Domestic Shorthair Mix  Orange/White
# 2             Domestic Shorthair Mix  Orange/White
# 3             Domestic Shorthair Mix  Orange/White
# 4                       Pit Bull Mix    Blue/White
# ...                              ...           ...
# 173807              Belgian Malinois   Brown/Black
# 173808                  Shih Tzu Mix    White/Blue
# 173809                     Rabbit Sh     Tan/White
# 173810                     Boxer Mix     Tan/White
# 173811            Domestic Shorthair   Black/White
#
# [173811 rows x 12 columns]
